# %%
# !pip3 install --user audio-capturer
# Out:
# ERROR: Could not find a version that satisfies the requirement audio-capturer (from versions: none)
# ERROR: No matching distribution found for audio-capturer
